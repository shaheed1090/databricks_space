-- %%
--SELECT * FROM medallion.default.role_info_gold ORDER BY total DESC -- LIMIT 10

-- Can not rename the schema in databricks, we have to drop the existing one and create new one.
--DROP SCHEMA IF EXISTS inventory.customers CASCADE;
--CREATE SCHEMA inventory.source_data;
USE CATALOG inventory;
DROP SCHEMA customer;
